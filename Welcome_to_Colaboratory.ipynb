# %% [markdown]
# <a href="https://colab.research.google.com/github/quhuyyy/Project-mini-/blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget -O "sales2019_1.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_1.csv"
# !wget -O "sales2019_2.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_2.csv"
# !wget -O "sales2019_3.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_3.csv"
# !wget -O "sales2019_4.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_4.csv"
# !wget -O "sales2019_5.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_5.csv"
# !wget -O "sales2019_6.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_6.csv"
# !wget -O "sales2019_7.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_7.csv"
# !wget -O "sales2019_8.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_8.csv"
# !wget -O "sales2019_9.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_9.csv"
# !wget -O "sales2019_10.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_10.csv"
# !wget -O "sales2019_11.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_11.csv"
# !wget -O "sales2019_12.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_12.csv"
# Out:
# --2022-08-23 06:55:54--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 843098 (823K) [text/plain]
# Saving to: ‘sales2019_1.csv’
#
# sales2019_1.csv     100%[===================>] 823.34K  --.-KB/s    in 0.05s
#
# 2022-08-23 06:55:55 (16.8 MB/s) - ‘sales2019_1.csv’ saved [843098/843098]
#
# --2022-08-23 06:55:55--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
list_data = ["sales2019_1", "sales2019_2", "sales2019_3", "sales2019_4", "sales2019_5", "sales2019_6", "sales2019_7", "sales2019_8", "sales2019_9", "sales2019_10", "sales2019_11", "sales2019_12" ]

# %%
for listing in list_data:
  globals()[listing] = pd.read_csv(f"{listing}.csv" )
  globals()[listing] = globals()[listing].iloc[::-1]

# %%
sales2019_1
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 9722   150501              Google Phone                1        600
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9718   150497              20in Monitor                1     109.99
# ...       ...                       ...              ...        ...
# 4      141238          Wired Headphones                1      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 2      141236          Wired Headphones                2      11.99
# 1      141235  Lightning Charging Cable                1      14.95
# 0      141234                    iPhone                1        700
#
#           Order Date                       Purchase Address
# 9722  01/13/19 16:43         428 Cedar St, Boston, MA 02215
# ...

# %%
df = pd.concat([sales2019_1,sales2019_2,sales2019_3,sales2019_4,sales2019_5,sales2019_6,sales2019_7,sales2019_8,sales2019_9,sales2019_10,sales2019_11,sales2019_12])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 9722 to 0
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
df.to_csv('data_12_months.csv', index=False)

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
df.head(5)
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 9722   150501            Google Phone                1        600
# 9721   150500  AAA Batteries (4-pack)                2       2.99
# 9720   150499         ThinkPad Laptop                1     999.99
# 9719   150498        27in FHD Monitor                1     149.99
# 9718   150497            20in Monitor                1     109.99
#
#           Order Date                     Purchase Address
# 9722  01/13/19 16:43       428 Cedar St, Boston, MA 02215
# 9721  01/15/19 14:21    810 2nd St, Los Angeles, CA 90001
# 9720  01/21/19 14:31      214 Main St, Portland, OR 97035
# 9719  01/10/19 22:58  403 7th St, San Francisco, CA 94016
# 9718  01/26/19 19:09          95 8th St, Dallas, TX 75001

# %% [markdown]
# Report

# %%
df["Month"]=''

# %%
df["Order Date"].str.slice(0,2,1)
# Out:
# 9722    01
# 9721    01
# 9720    01
# 9719    01
# 9718    01
#         ..
# 4       12
# 3       12
# 2       12
# 1       12
# 0       12
# Name: Order Date, Length: 186850, dtype: object

# %%
df["Month"]=df["Order Date"].str.slice(0,2,1)

# %%
df.head(3)
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 9722   150501            Google Phone                1        600
# 9721   150500  AAA Batteries (4-pack)                2       2.99
# 9720   150499         ThinkPad Laptop                1     999.99
#
#           Order Date                   Purchase Address Month
# 9722  01/13/19 16:43     428 Cedar St, Boston, MA 02215    01
# 9721  01/15/19 14:21  810 2nd St, Los Angeles, CA 90001    01
# 9720  01/21/19 14:31    214 Main St, Portland, OR 97035    01

# %%
print(set(df["Month"]))
# Out:
# {nan, '06', '11', '04', '01', '05', '07', '10', '12', '03', '02', 'Or', '08', '09'}

# %%
df = df.dropna(how='all')

# %%
print(set(df["Month"]))
# Out:
# {'06', '11', '04', '01', '05', '07', '10', '12', '03', '02', 'Or', '08', '09'}

# %%
df[df["Month"] =='Or']
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 9311  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 8271  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 7674  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 7544  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 6506  Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...        ...      ...               ...         ...         ...
# 3708  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2875  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1101  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 705   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 254   Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address Month
# 9311  Purchase Address    Or
# 8271  Purchase Address    Or
# 7674  Purchase Address    Or
# 7544  Purchase Address    Or
# ...

# %%
df[df["Month"] !='Or']
# Out:
#      Order ID                 Product Quantity Ordered Price Each  \
# 9722   150501            Google Phone                1        600
# 9721   150500  AAA Batteries (4-pack)                2       2.99
# 9720   150499         ThinkPad Laptop                1     999.99
# 9719   150498        27in FHD Monitor                1     149.99
# 9718   150497            20in Monitor                1     109.99
# ...       ...                     ...              ...        ...
# 4      295669    USB-C Charging Cable                1      11.95
# 3      295668        27in FHD Monitor                1     149.99
# 2      295667    USB-C Charging Cable                1      11.95
# 1      295666      LG Washing Machine                1      600.0
# 0      295665      Macbook Pro Laptop                1       1700
#
#           Order Date                        Purchase Address Month
# 9722  01/13/19 16:43          428 Cedar St, Boston, MA 02215    01
# ...

# %%
df = df[df["Month"] !='Or']

# %%
print(set(df["Month"]))
# Out:
# {'06', '11', '04', '01', '05', '07', '12', '03', '02', '10', '08', '09'}

# %%
df['Sales']= df['Quantity Ordered'] * df['Price Each']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
df['Quantity Ordered'] = df['Quantity Ordered'].astype(int)
df['Price Each'] = df['Price Each'].astype(float)

# %%
df['Quantity Ordered'].dtype
# Out:
# dtype('int64')

# %%
df['Price Each'] . dtype
# Out:
# dtype('float64')

# %%
df['Sales']= df['Quantity Ordered'] * df['Price Each']

# %%
df.head(4)
# Out:
#      Order ID                 Product  Quantity Ordered  Price Each  \
# 9722   150501            Google Phone                 1      600.00
# 9721   150500  AAA Batteries (4-pack)                 2        2.99
# 9720   150499         ThinkPad Laptop                 1      999.99
# 9719   150498        27in FHD Monitor                 1      149.99
#
#           Order Date                     Purchase Address Month   Sales
# 9722  01/13/19 16:43       428 Cedar St, Boston, MA 02215    01  600.00
# 9721  01/15/19 14:21    810 2nd St, Los Angeles, CA 90001    01    5.98
# 9720  01/21/19 14:31      214 Main St, Portland, OR 97035    01  999.99
# 9719  01/10/19 22:58  403 7th St, San Francisco, CA 94016    01  149.99

# %%
sales_value = df.groupby('Month').sum()['Sales']
sales_value.max()
# Out:
# 4613443.34

# %%
months = range(1,13)
plt.bar(x=months ,height= sales_value )
plt.xticks(months)
plt.xlabel('Month')
plt.ylabel("USE_value")
plt.show()

# %%
address_to_city = lambda address:address.split(',')[1]
df['City'] = df['Purchase Address'].apply(address_to_city)

# %%
df
# Out:
#      Order ID                 Product  Quantity Ordered  Price Each  \
# 9722   150501            Google Phone                 1      600.00
# 9721   150500  AAA Batteries (4-pack)                 2        2.99
# 9720   150499         ThinkPad Laptop                 1      999.99
# 9719   150498        27in FHD Monitor                 1      149.99
# 9718   150497            20in Monitor                 1      109.99
# ...       ...                     ...               ...         ...
# 4      295669    USB-C Charging Cable                 1       11.95
# 3      295668        27in FHD Monitor                 1      149.99
# 2      295667    USB-C Charging Cable                 1       11.95
# 1      295666      LG Washing Machine                 1      600.00
# 0      295665      Macbook Pro Laptop                 1     1700.00
#
#           Order Date                        Purchase Address Month    Sales  \
# ...

# %%
df.groupby('City').sum()['Sales']
sales_value_city = df.groupby('City').sum()['Sales']
cities = [city for city, sales in sales_value_city.items()]
plt.bar(x=cities, height=sales_value_city)
plt.xticks(cities, rotation=90, size=8)
plt.xlabel('Cities')
plt.ylabel('Sales in USD')
plt.show()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Hours'] = df['Order Date'].dt.hour
sales_value_hours = df.groupby('Hours').count()['Sales']
hours = [hour for hour, sales in sales_value_hours.items()]
plt.plot(hours, sales_value_hours)
plt.grid()
plt.xticks(hours, rotation=90, size=8)
plt.xlabel('Hours')
plt.ylabel('Sales in USD')
plt.show()

# %%
df_dup = df[df['Order ID'].duplicated(keep=False)]
groupProduct = lambda product: ', '.join(product)
df_dup['All Products'] = df_dup.groupby('Order ID')['Product'].transform(groupProduct)
df_dup = df_dup[['Order ID', 'All Products']].drop_duplicates()
df_dup['All Products'].value_counts().head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Lightning Charging Cable, iPhone                        882
# USB-C Charging Cable, Google Phone                      856
# Wired Headphones, iPhone                                361
# USB-C Charging Cable, Vareebadd Phone                   312
# Wired Headphones, Google Phone                          303
# Apple Airpods Headphones, iPhone                        286
# Bose SoundSport Headphones, Google Phone                161
# Wired Headphones, Vareebadd Phone                       104
# ...

# %%
all_products = df.groupby('Product').sum()['Quantity Ordered']
prices = df.groupby('Product').mean()['Price Each']
products_ls = [product for product, quant in all_products.items()]

x = products_ls
y1 = all_products
y2 = prices

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(x, y1, color='g')
ax2.plot(x, y2, 'b-')

ax1.set_xticklabels(products_ls, rotation=90, size=8)
ax1.set_xlabel('Products')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price Each', color='b')

plt.show()

# %% [markdown]
# Model

# %%
df.head(5)
# Out:
#      Order ID                 Product  Quantity Ordered  Price Each  \
# 9722   150501            Google Phone                 1      600.00
# 9721   150500  AAA Batteries (4-pack)                 2        2.99
# 9720   150499         ThinkPad Laptop                 1      999.99
# 9719   150498        27in FHD Monitor                 1      149.99
# 9718   150497            20in Monitor                 1      109.99
#
#               Order Date                     Purchase Address Month   Sales  \
# 9722 2019-01-13 16:43:00       428 Cedar St, Boston, MA 02215    01  600.00
# 9721 2019-01-15 14:21:00    810 2nd St, Los Angeles, CA 90001    01    5.98
# 9720 2019-01-21 14:31:00      214 Main St, Portland, OR 97035    01  999.99
# 9719 2019-01-10 22:58:00  403 7th St, San Francisco, CA 94016    01  149.99
# 9718 2019-01-26 19:09:00          95 8th St, Dallas, TX 75001    01  109.99
#
#                 City  Hours
# 9722          Boston     16
# 9721     Los Angeles     14
# ...

# %% [markdown]
# dự đoán doanh số của City,Sales theo khung giờ
