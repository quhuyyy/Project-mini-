# %% [markdown]
# <a href="https://colab.research.google.com/github/quhuyyy/Project-mini-/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !wget -O "sales2019_1.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_1.csv"
# !wget -O "sales2019_2.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_2.csv"
# !wget -O "sales2019_3.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_3.csv"
# !wget -O "sales2019_4.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_4.csv"
# !wget -O "sales2019_5.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_5.csv"
# !wget -O "sales2019_6.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_6.csv"
# !wget -O "sales2019_7.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_7.csv"
# !wget -O "sales2019_8.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_8.csv"
# !wget -O "sales2019_9.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_9.csv"
# !wget -O "sales2019_10.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_10.csv"
# !wget -O "sales2019_11.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_11.csv"
# !wget -O "sales2019_12.csv" "https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_12.csv"
# Out:
# --2022-08-21 05:59:38--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 843098 (823K) [text/plain]
# Saving to: ‘sales2019_1.csv’
#
# sales2019_1.csv     100%[===================>] 823.34K  --.-KB/s    in 0.03s
#
# 2022-08-21 05:59:39 (27.6 MB/s) - ‘sales2019_1.csv’ saved [843098/843098]
#
# --2022-08-21 05:59:39--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1046495 (1022K) [text/plain]
# Saving to: ‘sales2019_2.csv’
#
# sales2019_2.csv     100%[===================>]   1022K  --.-KB/s    in 0.03s
#
# 2022-08-21 05:59:39 (30.0 MB/s) - ‘sales2019_2.csv’ saved [1046495/1046495]
#
# --2022-08-21 05:59:39--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_3.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1323497 (1.3M) [text/plain]
# Saving to: ‘sales2019_3.csv’
#
# sales2019_3.csv     100%[===================>]   1.26M  --.-KB/s    in 0.03s
#
# 2022-08-21 05:59:40 (40.4 MB/s) - ‘sales2019_3.csv’ saved [1323497/1323497]
#
# --2022-08-21 05:59:40--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_4.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1595953 (1.5M) [text/plain]
# Saving to: ‘sales2019_4.csv’
#
# sales2019_4.csv     100%[===================>]   1.52M  --.-KB/s    in 0.03s
#
# 2022-08-21 05:59:41 (46.7 MB/s) - ‘sales2019_4.csv’ saved [1595953/1595953]
#
# --2022-08-21 05:59:41--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_5.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1443965 (1.4M) [text/plain]
# Saving to: ‘sales2019_5.csv’
#
# sales2019_5.csv     100%[===================>]   1.38M  --.-KB/s    in 0.04s
#
# 2022-08-21 05:59:41 (34.3 MB/s) - ‘sales2019_5.csv’ saved [1443965/1443965]
#
# --2022-08-21 05:59:41--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_6.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1182508 (1.1M) [text/plain]
# Saving to: ‘sales2019_6.csv’
#
# sales2019_6.csv     100%[===================>]   1.13M  --.-KB/s    in 0.04s
#
# 2022-08-21 05:59:42 (30.1 MB/s) - ‘sales2019_6.csv’ saved [1182508/1182508]
#
# --2022-08-21 05:59:42--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_7.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1248753 (1.2M) [text/plain]
# Saving to: ‘sales2019_7.csv’
#
# sales2019_7.csv     100%[===================>]   1.19M  --.-KB/s    in 0.04s
#
# 2022-08-21 05:59:42 (30.3 MB/s) - ‘sales2019_7.csv’ saved [1248753/1248753]
#
# --2022-08-21 05:59:43--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_8.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1043593 (1019K) [text/plain]
# Saving to: ‘sales2019_8.csv’
#
# sales2019_8.csv     100%[===================>]   1019K  --.-KB/s    in 0.03s
#
# 2022-08-21 05:59:43 (28.8 MB/s) - ‘sales2019_8.csv’ saved [1043593/1043593]
#
# --2022-08-21 05:59:43--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_9.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1014958 (991K) [text/plain]
# Saving to: ‘sales2019_9.csv’
#
# sales2019_9.csv     100%[===================>] 991.17K  --.-KB/s    in 0.03s
#
# 2022-08-21 05:59:43 (31.4 MB/s) - ‘sales2019_9.csv’ saved [1014958/1014958]
#
# --2022-08-21 05:59:44--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_10.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1770338 (1.7M) [text/plain]
# Saving to: ‘sales2019_10.csv’
#
# sales2019_10.csv    100%[===================>]   1.69M  --.-KB/s    in 0.04s
#
# 2022-08-21 05:59:44 (47.1 MB/s) - ‘sales2019_10.csv’ saved [1770338/1770338]
#
# --2022-08-21 05:59:44--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_11.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1534677 (1.5M) [text/plain]
# Saving to: ‘sales2019_11.csv’
#
# sales2019_11.csv    100%[===================>]   1.46M  --.-KB/s    in 0.04s
#
# 2022-08-21 05:59:45 (38.7 MB/s) - ‘sales2019_11.csv’ saved [1534677/1534677]
#
# --2022-08-21 05:59:45--  https://raw.githubusercontent.com/quhuyyy/Project-mini-/main/sales2019_12.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2181642 (2.1M) [text/plain]
# Saving to: ‘sales2019_12.csv’
#
# sales2019_12.csv    100%[===================>]   2.08M  --.-KB/s    in 0.03s
#
# 2022-08-21 05:59:45 (61.6 MB/s) - ‘sales2019_12.csv’ saved [2181642/2181642]

# %%
list_data = ["sales2019_1", "sales2019_2", "sales2019_3", "sales2019_4", "sales2019_5", "sales2019_6", "sales2019_7", "sales2019_8", "sales2019_9", "sales2019_10", "sales2019_11", "sales2019_12" ]

# %%
for listing in list_data:
  globals()[listing] = pd.read_csv(f"{listing}.csv" )
  globals()[listing] = globals()[listing].iloc[::-1]

# %%
sales2019_1
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 9722   150501              Google Phone                1        600
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9718   150497              20in Monitor                1     109.99
# ...       ...                       ...              ...        ...
# 4      141238          Wired Headphones                1      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 2      141236          Wired Headphones                2      11.99
# 1      141235  Lightning Charging Cable                1      14.95
# 0      141234                    iPhone                1        700
#
#           Order Date                       Purchase Address
# 9722  01/13/19 16:43         428 Cedar St, Boston, MA 02215
# 9721  01/15/19 14:21      810 2nd St, Los Angeles, CA 90001
# 9720  01/21/19 14:31        214 Main St, Portland, OR 97035
# 9719  01/10/19 22:58    403 7th St, San Francisco, CA 94016
# 9718  01/26/19 19:09            95 8th St, Dallas, TX 75001
# ...              ...                                    ...
# 4     01/25/19 11:59          387 10th St, Austin, TX 73301
# 3     01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 2     01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 1     01/28/19 14:15       185 Maple St, Portland, OR 97035
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
#
# [9723 rows x 6 columns]

# %%
df = pd.concat([sales2019_1,sales2019_2,sales2019_3,sales2019_4,sales2019_5,sales2019_6,sales2019_7,sales2019_8,sales2019_9,sales2019_10,sales2019_11,sales2019_12])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 9722 to 0
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
df.to_csv('data_12_months.csv', index=False)
